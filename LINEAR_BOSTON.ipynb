# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexandermontes/cross_var/blob/main/LINEAR_BOSTON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston



datos = load_boston()

df = pd.DataFrame(datos.data, columns=datos.feature_names)
df['MEDV'] =datos.target

x=df[['RM']]
y=df['MEDV']

print(x.shape)
print(y.shape)

x_train, x_test, y_train, y_test  = train_test_split(x,y, test_size=0.3, random_state=12)
model = LinearRegression()
model.fit(x_train, y_train)
pred = model.predict(x_test)


plt.scatter(x, y)
plt.plot(x_test, pred)
plt.show()
# Out:
# (506, 1)
# (506,)
